# %% [markdown]
# Expected Value vs. CVaR Comparison
#
# Mauricio Tombini, Jordan Jalving, and Victor M. Zavala
#
# University of Wisconsin-Madison, 2016

# %%
# Loading packages:
using JuMP 
using Distributions 
using Ipopt
using PyPlot

# %%
# Generate random data: 
NS = 100
S = collect(1:NS); 
srand(0)
μ = 0; σ = 2; 
d = Normal(μ,σ)
R = rand(d,NS);

# %%
# Plotting data
plt[:hist](R, bins = 30);
grid("on")
xlabel(L"\xi")
ylabel(L"p(\xi)")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f953ac35e90>)
# PyObject <matplotlib.text.Text object at 0x7f953adb3210>

# %% [markdown]
# ## Solve expected value problem

# %%
m = Model(solver=IpoptSolver(print_level=0))

@variable(m, x)            # decision variable
@variable(m, cost[1:NS])   # per scenario cost
@constraint(m, costeq[s in S], cost[s] == (x-R[s])^2 - R[s]*x) 
@objective(m, Min, (1/NS)*sum(cost[s] for s in S))

solve(m)
solcost = getvalue(cost);
println("x=",getvalue(x))
println("mean=",getobjectivevalue(m))
# Out:
# x=-0.07446144464990463
# mean=4.41530627977073

# %%
# Plotting cost fistribution 
plt[:hist](solcost,bins = 30)
grid("on")
axis([-10, 50, 0, 50])
xlabel(L"f(x^*(\xi),\xi)")
ylabel(L"p(f(\cdot))")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f953a2c1810>)
# PyObject <matplotlib.text.Text object at 0x7f953a069350>

# %% [markdown]
# ## Solve CVaR Problem

# %%
m = Model(solver=IpoptSolver(print_level=0))

@variable(m, x)              # decision variable
@variable(m, cost[1:NS])     # per scenario cost
@variable(m, VaR)            # cvar auxiliary variable
@variable(m, phi[S] >= 0)    # cvar auxiliary variable
alpha = 0.0001;              # cvar probability level

@constraint(m, costeq[s in S], cost[s] == (x-R[s])^2 - R[s]*x) 
@constraint(m, cvar[s in S], cost[s]-VaR <= phi[s])
@objective(m, Min, VaR + (1/NS)*sum((1/alpha)*phi[s] for s in S))

solve(m)
solcost2 = getvalue(cost);
println("x=",getvalue(x))
println("CVaR=",getobjectivevalue(m))
println("mean=",(1/NS)*sum(solcost2))
# Out:
# x=-0.769049339750124
# CVaR=32.68240413393139
# mean=4.897758625514248

# %%
# Plotting cost distribution 
plt[:hist](solcost2,bins = 30)
grid("on")
axis([-10, 50, 0, 50])
xlabel(L"f(x^*(\xi),\xi)")
ylabel(L"p(f(\cdot))")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f9539d76e10>)
# PyObject <matplotlib.text.Text object at 0x7f953a132a10>
