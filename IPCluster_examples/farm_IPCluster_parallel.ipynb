# %%
run(`mpirun -np 2 /opt/julia-0.4.5/bin/julia farm_IPCluster.jl`)
# Out:
# INFO: Recompiling stale cache file /home/jordan/.julia/lib/v0.5/MathProgBase.ji for module MathProgBase.
# INFO: Recompiling stale cache file /home/jordan/.julia/lib/v0.5/MathProgBase.ji for module MathProgBase.
# WARNING: Method definition setsense!() in module SolverInterface at /home/jordan/.julia/v0.5/MathProgBase/src/SolverInterface/SolverInterface.jl:11 overwritten at /home/jordan/.julia/v0.5/MathProgBase/src/SolverInterface/SolverInterface.jl:11.
# WARNING: Method definition setsense!(Int64) in module SolverInterface at /home/jordan/.julia/v0.5/MathProgBase/src/SolverInterface/SolverInterface.jl:13 overwritten at /home/jordan/.julia/v0.5/MathProgBase/src/SolverInterface/SolverInterface.jl:13.
# WARNING: Method definition setvartype!() in module SolverInterface at /home/jordan/.julia/v0.5/MathProgBase/src/SolverInterface/SolverInterface.jl:11 overwritten at /home/jordan/.julia/v0.5/MathProgBase/src/SolverInterface/SolverInterface.jl:11.
# ...
